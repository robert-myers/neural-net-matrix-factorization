# %% [markdown]
# <a href="https://colab.research.google.com/github/robert-myers/neural-net-matrix-factorization-reloaded/blob/master/nnmfr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %%
import tensorflow as tf

# %%
# !python scripts/split_data.py
# Out:
# Reading in data
# Data subsets:
# Train: 88200
# Validation: 1800
# Test: 10000

# %%
# %%time
# !python main.py --model NNMF --mode train
# Out:
# 2020-02-29 00:00:10.566832: E tensorflow/stream_executor/cuda/cuda_driver.cc:351] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Building network & initializing variables
# WARNING:tensorflow:From /tensorflow-2.1.0/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1635: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-2.1.0/python3.6/tensorflow_core/python/util/tf_should_use.py:235: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Reading in data
# [start] Train error: 80634.242188, Train RMSE: 1.795773; Valid RMSE: 1.793600
# ...

# %%
# %%time
# !python main.py --model NNMF --mode select
# Out:
# Streaming output truncated to the last 5000 lines.
# [194-2] Train error: 29142.677734, Train RMSE: 1.056784; Valid RMSE: 1.066110
# [194-3] Train error: 15952.297852, Train RMSE: 1.056586; Valid RMSE: 1.065854
# [195-0] Train error: 28614.064453, Train RMSE: 1.046779; Valid RMSE: 1.065433
# [195-1] Train error: 28574.001953, Train RMSE: 1.045815; Valid RMSE: 1.064956
# [195-2] Train error: 29482.548828, Train RMSE: 1.062703; Valid RMSE: 1.064272
# [195-3] Train error: 15916.902344, Train RMSE: 1.054365; Valid RMSE: 1.063995
# [196-0] Train error: 28484.685547, Train RMSE: 1.043822; Valid RMSE: 1.063541
# [196-1] Train error: 28814.019531, Train RMSE: 1.049874; Valid RMSE: 1.062949
# [196-2] Train error: 29035.507812, Train RMSE: 1.053683; Valid RMSE: 1.062239
# [196-3] Train error: 15925.704102, Train RMSE: 1.053621; Valid RMSE: 1.061935
# [197-0] Train error: 28576.257812, Train RMSE: 1.045027; Valid RMSE: 1.061558
# ...
